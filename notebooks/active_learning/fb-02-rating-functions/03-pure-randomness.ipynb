# %% [markdown]
# ### [Experiment] What are our results if we use a purely random Selection Algorithm on a purely random Oracle?

# %%
import os, sys
os.chdir(os.path.join('..','..','..')) # set working directory to root of github repo

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from active_learning.evaluation import *
from active_learning.rating import randomly

# %%
oracle = FunctionalOracle
oracle_params = {'rating_func': randomly}

algorithm = RandomSelectionAlgorithm
algo_params = {}

# %%
evaluator = Evaluator(algorithm=algorithm, algo_params=algo_params,
                     oracle=oracle, oracle_params=oracle_params,
                     batch_size=1, dataset_name='Rotten Tomato')

# %%
stats = evaluator.compute()
stats['mse'].plot()
stats['absolute_error'].plot()

# %%
evaluator = Evaluator(algorithm=algorithm, algo_params=algo_params,
                     oracle=oracle, oracle_params=oracle_params,
                     batch_size=1, dataset_name='Programming Languages OOvsWeb [Freebase] - length 3')
# Out:
# CYPHERDATASETLOADER: Number of meta-paths is 278

# %%
stats = evaluator.compute()
stats['mse'].plot()
stats['absolute_error'].plot()
